# %%
# %run ../notebooks/00_setup_paths.ipynb
# Out:
# utils/ folder added to Python import path
# project_root:     C:\Users\akaas\crime-projectMain
# raw_dir:          C:\Users\akaas\crime-projectMain\data
# parquet_dir:      C:\Users\akaas\crime-projectMain\data_parquet
# processed_dir:    C:\Users\akaas\crime-projectMain\data_processed
# models_dir:       C:\Users\akaas\crime-projectMain\models
# logs_dir:         C:\Users\akaas\crime-projectMain\logs
# utils_dir:        C:\Users\akaas\crime-projectMain\utils

# %%
from spark_init import init_spark
spark = init_spark("CrimeProject_Phase3", driver_memory="12g")
spark
# Out:
# Spark Initialized: CrimeProject_Phase3
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://Akaash.lan:4042">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v4.0.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>CrimeProject_Phase3</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
from pathlib import Path

master_dir = processed_dir / "incidents_master"
incident_df = spark.read.parquet(str(master_dir))

print("Loaded incident_master")
incident_df.printSchema()
# Out:
# Loaded incident_master
# root
#  |-- unique_incident_id: string (nullable = true)
#  |-- city_submissions: string (nullable = true)
#  |-- cleared_exceptionally: string (nullable = true)
#  |-- exceptional_clearance_date: string (nullable = true)
#  |-- incident_date: string (nullable = true)
#  |-- incident_date_hour: string (nullable = true)
#  |-- incident_number: string (nullable = true)
#  |-- ori: string (nullable = true)
#  |-- report_date_indicator: string (nullable = true)
#  |-- state: string (nullable = true)
#  |-- state_abb: string (nullable = true)
#  |-- total_arrestee_segments: string (nullable = true)
#  |-- total_offender_segments: string (nullable = true)
#  |-- total_offense_segments: string (nullable = true)
#  |-- total_victim_segments: string (nullable = true)
#  |-- year: string (nullable = true)
#  |-- offense_codes: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- num_offenses: long (nullable = true)
#  |-- num_victims: long (nullable = true)
#  |-- num_offenders: long (nullable = true)
#  |-- total_property_value: double (nullable = true)
#  |-- num_arrestees: long (nullable = true)

# %%
from pyspark.sql.functions import col

base_cols = [
    "unique_incident_id",
    "ori",
    "state",
    "year",
    "incident_date",
    "offense_codes",
    "num_offenses",
    "num_victims",
    "num_offenders",
    "total_property_value",
    "num_arrestees"
]

df = incident_df.select(*base_cols)
print("Selected base columns.")
# Out:
# Selected base columns.

# %%
from pyspark.sql.functions import to_date

df = df.withColumn("date", to_date("incident_date", "yyyy-MM-dd"))
df = df.drop("incident_date")

df = df.filter(col("date").isNotNull())
print("Converted dates.")
# Out:
# Converted dates.

# %%
from pyspark.sql.functions import count, sum as spark_sum

daily = (
    df.groupBy("ori", "date")
    .agg(
        count("*").alias("daily_incidents"),
        spark_sum("num_victims").alias("daily_victims"),
        spark_sum("num_offenders").alias("daily_offenders"),
        spark_sum("num_arrestees").alias("daily_arrestees"),
        spark_sum("num_offenses").alias("daily_offense_count"),
        spark_sum("total_property_value").alias("daily_property_loss")
    )
)

# %%
from pyspark.sql.functions import explode

flat = df.select("ori", "date", explode("offense_codes").alias("code"))

offense_dist = (
    flat.groupBy("ori", "date", "code")
        .agg(count("*").alias("code_count"))
)

# pivot to wide format
offense_pivot = (
    offense_dist.groupBy("ori", "date")
        .pivot("code")
        .sum("code_count")
)

# fill missing codes with 0
offense_pivot = offense_pivot.fillna(0)

# %%
daily_full = (
    daily.join(offense_pivot, ["ori", "date"], "left")
         .fillna(0)
)

# %%
from pyspark.sql.functions import dayofweek, weekofyear, month, year

daily_full = (
    daily_full
    .withColumn("dow", dayofweek("date"))
    .withColumn("week", weekofyear("date"))
    .withColumn("month", month("date"))
    .withColumn("year_val", year("date"))
)

# %%
weekly = (
    daily_full.groupBy("ori", "year_val", "week")
        .agg(
            spark_sum("daily_incidents").alias("week_incidents"),
            spark_sum("daily_victims").alias("week_victims"),
            spark_sum("daily_offenders").alias("week_offenders"),
            spark_sum("daily_property_loss").alias("week_property_loss")
        )
)

# %%
from pyspark.sql.window import Window
from pyspark.sql.functions import lag

w = Window.partitionBy("ori").orderBy("date")

lags = [1, 7, 14, 30]

for l in lags:
    daily_full = daily_full.withColumn(f"lag_{l}", lag("daily_incidents", l).over(w))

# %%
from pyspark.sql.functions import avg

for win in [7, 14, 30]:
    w2 = Window.partitionBy("ori").orderBy("date").rowsBetween(-win, 0)
    daily_full = daily_full.withColumn(
        f"ma_{win}",
        avg("daily_incidents").over(w2)
    )

# %%
from pyspark.sql.functions import sum as spark_sum

w3 = Window.partitionBy("ori").orderBy("date").rowsBetween(-3, -1)

daily_full = daily_full.withColumn(
    "near_repeat_3d",
    spark_sum("daily_incidents").over(w3)
)

daily_full = daily_full.fillna(0)

# %%
combined = (
    daily_full.join(
        weekly,
        on=["ori", "year_val", "week"],
        how="left"
    )
    .fillna(0)
)

print("Final feature matrix prepared.")
combined.printSchema()
# Out:
# Final feature matrix prepared.
# root
#  |-- ori: string (nullable = true)
#  |-- year_val: integer (nullable = true)
#  |-- week: integer (nullable = true)
#  |-- date: date (nullable = true)
#  |-- daily_incidents: long (nullable = false)
#  |-- daily_victims: long (nullable = true)
#  |-- daily_offenders: long (nullable = true)
#  |-- daily_arrestees: long (nullable = true)
#  |-- daily_offense_count: long (nullable = true)
#  |-- daily_property_loss: double (nullable = false)
#  |-- animal cruelty: long (nullable = true)
#  |-- arson: long (nullable = true)
#  |-- assault offenses - aggravated assault: long (nullable = true)
#  |-- assault offenses - intimidation: long (nullable = true)
#  |-- assault offenses - simple assault: long (nullable = true)
#  |-- bribery: long (nullable = true)
#  |-- burglary/breaking and entering: long (nullable = true)
#  |-- commerce violations - federal liquor offenses: long (nullable = true)
#  |-- commerce violations - federal tobacco offenses: long (nullable = true)
#  |-- commerce violations - wildlife trafficking: long (nullable = true)
#  |-- counterfeiting/forgery: long (nullable = true)
#  |-- destruction/damage/vandalism of property: long (nullable = true)
#  |-- drug/narcotic offenses - drug equipment violations: long (nullable = true)
#  |-- drug/narcotic offenses - drug/narcotic violations: long (nullable = true)
#  |-- embezzlement: long (nullable = true)
#  |-- extortion/blackmail: long (nullable = true)
#  |-- fraud offenses - credit card/atm fraud: long (nullable = true)
#  |-- fraud offenses - false pretenses/swindle/confidence game: long (nullable = true)
#  |-- fraud offenses - hacking/computer invasion: long (nullable = true)
#  |-- fraud offenses - identity theft: long (nullable = true)
#  |-- fraud offenses - impersonation: long (nullable = true)
#  |-- fraud offenses - money laundering: long (nullable = true)
#  |-- fraud offenses - welfare fraud: long (nullable = true)
#  |-- fraud offenses - wire fraud: long (nullable = true)
#  |-- fugitive offenses - flight to avoid deportation: long (nullable = true)
#  |-- fugitive offenses - flight to avoid prosecution: long (nullable = true)
#  |-- fugitive offenses - harboring escapee - concealing from arrest: long (nullable = true)
#  |-- gambling offenses - betting/wagering: long (nullable = true)
#  |-- gambling offenses - gambling equipment violations: long (nullable = true)
#  |-- gambling offenses - operating/promoting/assisting gambling: long (nullable = true)
#  |-- gambling offenses - sports tampering: long (nullable = true)
#  |-- human trafficking - commercial sex acts: long (nullable = true)
#  |-- human trafficking - involuntary servitude: long (nullable = true)
#  |-- immigration violations - illegal entry into the united states: long (nullable = true)
#  |-- immigration violations - smuggling aliens: long (nullable = true)
#  |-- justifiable homicide - not a crime: long (nullable = true)
#  |-- kidnapping/abduction: long (nullable = true)
#  |-- larceny/theft offenses - all other larceny: long (nullable = true)
#  |-- larceny/theft offenses - pocket-picking: long (nullable = true)
#  |-- larceny/theft offenses - purse-snatching: long (nullable = true)
#  |-- larceny/theft offenses - shoplifting: long (nullable = true)
#  |-- larceny/theft offenses - theft from building: long (nullable = true)
#  |-- larceny/theft offenses - theft from coin-operated machine or device: long (nullable = true)
#  |-- larceny/theft offenses - theft from motor vehicle: long (nullable = true)
#  |-- larceny/theft offenses - theft of motor vehicle parts/accessories: long (nullable = true)
#  |-- motor vehicle theft: long (nullable = true)
#  |-- murder/nonnegligent manslaughter: long (nullable = true)
#  |-- negligent manslaughter: long (nullable = true)
#  |-- pornography/obscene material: long (nullable = true)
#  |-- prostitution offenses - assisting or promoting prostitution: long (nullable = true)
#  |-- prostitution offenses - prostitution: long (nullable = true)
#  |-- prostitution offenses - purchasing prostitution: long (nullable = true)
#  |-- robbery: long (nullable = true)
#  |-- sex offenses - criminal sexual contact (formerly: fondling (indecent liberties/child molest)): long (nullable = true)
#  |-- sex offenses - failure to register as a sex offender: long (nullable = true)
#  |-- sex offenses - incest: long (nullable = true)
#  |-- sex offenses - rape: long (nullable = true)
#  |-- sex offenses - sexual assault with an object: long (nullable = true)
#  |-- sex offenses - sodomy: long (nullable = true)
#  |-- sex offenses - statutory rape: long (nullable = true)
#  |-- stolen property offenses (receiving, selling, etc.): long (nullable = true)
#  |-- weapon law violations - explosives: long (nullable = true)
#  |-- weapon law violations - violation of national firearm act of 1934: long (nullable = true)
#  |-- weapon law violations - weapon law violations: long (nullable = true)
#  |-- weapon law violations - weapons of mass destruction: long (nullable = true)
#  |-- dow: integer (nullable = true)
#  |-- month: integer (nullable = true)
#  |-- lag_1: long (nullable = true)
#  |-- lag_7: long (nullable = true)
#  |-- lag_14: long (nullable = true)
#  |-- lag_30: long (nullable = true)
#  |-- ma_7: double (nullable = false)
#  |-- ma_14: double (nullable = false)
#  |-- ma_30: double (nullable = false)
#  |-- near_repeat_3d: long (nullable = true)
#  |-- week_incidents: long (nullable = true)
#  |-- week_victims: long (nullable = true)
#  |-- week_offenders: long (nullable = true)
#  |-- week_property_loss: double (nullable = false)

# %%
phase3_dir = processed_dir / "phase3_features"
phase3_dir.mkdir(exist_ok=True)

combined.write.mode("overwrite").parquet(str(phase3_dir))

print("Phase 3 dataset saved:", phase3_dir)
# Out:
# Phase 3 dataset saved: C:\Users\akaas\crime-projectMain\data_processed\phase3_features
